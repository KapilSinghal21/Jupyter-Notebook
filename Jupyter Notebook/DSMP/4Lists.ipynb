# %% [markdown]
# # Lists

# %%
# id function Provides Memory Address 
a = 5
print(id(5))
# Out:
# 140735208269048

# %%
L = [1,2,3] 
print(id(L))
print(id(L[0]))
print(id(L[1]))
print(id(L[2]))
print(id(1))
print(id(2))
print(id(3))
# Out:
# 2489561004800
# 140735208268920
# 140735208268952
# 140735208268984
# 140735208268920
# 140735208268952
# 140735208268984
